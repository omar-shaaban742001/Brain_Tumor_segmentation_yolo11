# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 24.2 MB/s eta 0:00:00
# ...

# %%
# !yolo task = segment mode=train model=yolo11l-seg.pt data=/content/data.yaml epochs=100 imgsz=640 batch=16
# Out:
# ...
# 100% 53.5M/53.5M [00:00<00:00, 112MB/s]
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
